# %% [markdown]
# # Inteligencja Obliczeniowa w Analizie Danych Cyfrowych
#
# ##	Projekt I
#
# ### Autorzy
# - Dominik Breksa
# - Robert Barcik
# - Konrad Bodzioch
#
# Download all the necessary packages to run this `.ipynb` script.
#
# Python version: `3.12.2`
# Used packages:
# - *numpy*, `1.26.4`
# - *pandas*, `2.8.2`
# - *matplotlib*, `3.8.3`
# - *easyAI*, `2.0.12`

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install easyAI
# Out:
# Requirement already satisfied: numpy in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (1.26.1)
# Requirement already satisfied: pandas in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: easyAI in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (2.0.12)
# Requirement already satisfied: numpy in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from easyAI) (1.26.1)

# %% [markdown]
# Import all the necessary packages to run this `.ipynb` script.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Nimby
#
# Nimby game created as described in the task. Probabilistic model added in make_move method.
# Added typing to help with code completion and readability.

# %%
from easyAI.games import Nim
from typing import Optional, Final, ClassVar
from random import random

from easyAI import TwoPlayerGame, AI_Player


class Nimby(Nim):
    MUTATION_PROBABILITY: ClassVar[float] = 0.1
    
    def make_move(self, move: str) -> None:
        where, count = tuple(map(int, move.split(",")))
        #   Added randomness as described in the task
        if Nimby.MUTATION_PROBABILITY >= random():
            remove = count - 1
        else:
            remove = count

        self.piles[where - 1] -= remove

def ask_move_modified(self, game):
    # Make so that AI makes predictions as if the game was deterministic. This enables the AI to make mistakes based on randomness later, when game performs a move. Making sure that the AI doesn't predict wrong and build turn tree with wrong values.
    original_make_move = game.make_move
    game.make_move = Nim.make_move.__get__(game, Nim)
    move = self.AI_algo(game)
    game.make_move = original_make_move
    
    return move

# Dirty Hack, so that I don't have to create 3 classes (Nimby, Nim, TwoPlayerGame) once again to change one function.
ask_move_original = AI_Player.ask_move
AI_Player.ask_move = ask_move_modified

# %% [markdown]
# Make randomness seed deterministic.

# %%
from random import seed

seed(42)

# %% [markdown]
# Simple test of the Nimby game, to check if it works.

# %%
from easyAI import AI_Player, Negamax
from easyAI.AI import TranspositionTable

#   Test
ai1: Negamax = Negamax(8, tt=TranspositionTable())
ai2: Negamax = Negamax(4, tt=TranspositionTable())
nimby: Nimby = Nimby([AI_Player(ai1), AI_Player(ai2)])
nimby.play()

'player %d wins' % nimby.current_player
# Out:
# 'player 1 wins'

# %% [markdown]
# ### Negamax - Deterministic
#
# 1. Firstly we solve the Nim game using the `easyAI` library, in order to see max depth (`d == 14`) for perfect AI.
# 2. We can also acknowledge the fact that the first player will always lose (`w == -1`), and the perfect move is `1,1`

# %%
from easyAI import solve_with_iterative_deepening

from easyAI.games import Nim

perfect_table: TranspositionTable = TranspositionTable()
w, d, m = solve_with_iterative_deepening(Nim(), range(1, 25), win_score=80, tt=perfect_table)
w, d, m, len(perfect_table.d)
# Out:
# d:1, a:0, m:1,1
# d:2, a:0, m:1,1
# d:3, a:0, m:1,1
# d:4, a:0, m:1,1
# d:5, a:0, m:1,1
# d:6, a:0, m:1,1
# d:7, a:0, m:1,1
# d:8, a:0, m:1,1
# d:9, a:0, m:1,1
# d:10, a:0, m:1,1
# d:11, a:0, m:1,1
# d:12, a:0, m:1,1
# d:13, a:0, m:1,1
# d:14, a:-100, m:1,1
# (-1, 14, '1,1', 1100)

# %%
MAX_DEPTH: Final[int] = d

# Create a pandas dataframe to store the results
df: pd.DataFrame = pd.DataFrame(columns=['game_variant', 'algorithm', 'depths', 'starting_player', 'winner', 'time', 'rounds'])

# If you have the computing power you can test all the possible combinations of depths, since the game is deterministic, you will always get the same results.
# from itertools import product
# config: Final[list[tuple[int, int]]] = list(product(range(1, max_depth + 1), repeat=2))

# Tests as described in task.
CONFIG_NIM: Final[list[tuple[int, int]]] = [
    (MAX_DEPTH, MAX_DEPTH // 2),
    (MAX_DEPTH // 3, MAX_DEPTH // 4),
]

CONFIG_NIM
# Out:
# [(14, 7), (4, 3)]

# %%
df
# Out:
# Empty DataFrame
# Columns: [game_variant, algorithm, depths, starting_player, winner, time, rounds]
# Index: []

# %%
from typing import Callable, Any
from time import perf_counter

type DepthConfiguration = tuple[int, int]
type DataframeRecord = tuple[str, str, np.array, np.uint8, np.uint8, float, np.uint8]

def create_environment(*, game_type: type(TwoPlayerGame), solving_algorithm: Any, in_order: bool, **kwargs) -> Callable[[DepthConfiguration], DataframeRecord]:
    def play_game(depths: DepthConfiguration) -> DataframeRecord:
        player1_depth, player2_depth = depths
        ai_1: solving_algorithm = solving_algorithm(depth=player1_depth, tt=TranspositionTable())
        ai_2: solving_algorithm = solving_algorithm(depth=player2_depth, tt=TranspositionTable())
        game_config: dict[str, Any] = {
            'players': [
                AI_Player(ai_1),
                AI_Player(ai_2)
            ],
        } | kwargs
        
        environment: game_type = game_type(**game_config)
        
        if not in_order:
            environment.switch_player()
    
        starting_player: int = environment.current_player
    
        start: float = perf_counter()
        history: list = environment.play()
        end: float = perf_counter()

        output: DataframeRecord = str(game_type.__name__), str(solving_algorithm.__name__), np.asarray(depths), np.uint8(starting_player),  np.uint8(environment.current_player), end - start, np.uint8(len(history) - 1)

        print(
            '======== Finished(game_type=\'{}\', solving_algorithm=\'{}\')(depths={}, starting_player={}, winner={}, time={}s, rounds_number={}) ========'.format(
                *output
            )
        )
        return output
    
    return play_game

def add_to_dataframe(data: pd.DataFrame, records: list[DataframeRecord]) -> None:
    for record in records:
        data.loc[len(data)] = record

# %%
results: map = map(create_environment(game_type=Nim, solving_algorithm=Negamax, in_order=True), CONFIG_NIM)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nim', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.4890574002638459s, rounds_number=14) ========
# ======== Finished(game_type='Nim', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.10446090018376708s, rounds_number=17) ========

# %%
results: map = map(create_environment(game_type=Nim, solving_algorithm=Negamax, in_order=False), CONFIG_NIM)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nim', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=1, time=0.6386898001655936s, rounds_number=17) ========
# ======== Finished(game_type='Nim', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=1, time=0.08502970030531287s, rounds_number=17) ========

# %%
df.dtypes
# Out:
# game_variant        object
# algorithm           object
# depths              object
# starting_player      uint8
# winner               uint8
# time               float64
# rounds               uint8
# dtype: object

# %%
df
# Out:
#   game_variant algorithm   depths  starting_player  winner      time  rounds
# 0          Nim   Negamax  [14, 7]                1       1  0.489057      14
# 1          Nim   Negamax   [4, 3]                1       2  0.104461      17
# 2          Nim   Negamax  [14, 7]                2       1  0.638690      17
# 3          Nim   Negamax   [4, 3]                2       1  0.085030      17

# %% [markdown]
# ### Negamax - Non-Deterministic

# %%
from itertools import chain

REPEAT_COUNT: Final[int] = 10

CONFIG_NIMBY: Final[list[tuple[int, int]]] = list(chain.from_iterable([[element] * REPEAT_COUNT for element in CONFIG_NIM]))

CONFIG_NIMBY
# Out:
# [(14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (14, 7),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3),
#  (4, 3)]

# %%
results: map = map(create_environment(game_type=Nimby, solving_algorithm=Negamax, in_order=True), CONFIG_NIMBY)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.592242100276053s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.5230817003175616s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.48067659977823496s, rounds_number=14) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.5764518999494612s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=2, time=0.577761699911207s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.5816955002956092s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.5870387000031769s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.5618389998562634s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=1, time=0.4774092002771795s, rounds_number=14) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=1, winner=2, time=0.5174835002981126s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.11010150006040931s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=1, time=0.12239360017701983s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.12023569969460368s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=1, time=0.09590629953891039s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.10950159979984164s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.10835080035030842s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.10429439973086119s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=1, time=0.10043929982930422s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=1, time=0.11213649995625019s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=1, winner=2, time=0.09711780026555061s, rounds_number=17) ========

# %%
results: map = map(create_environment(game_type=Nimby, solving_algorithm=Negamax, in_order=False), CONFIG_NIMBY)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=1, time=0.7637060997076333s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=2, time=0.6870307996869087s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=2, time=0.6830739001743495s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=2, time=0.6788754998706281s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=1, time=0.6639753002673388s, rounds_number=15) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=2, time=0.6947727999649942s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=2, time=0.6944345999509096s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=2, time=0.6864148997701705s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=1, time=0.7281252001412213s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[14  7], starting_player=2, winner=1, time=0.6641308004036546s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=1, time=0.11200649989768863s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=1, time=0.10647300025448203s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=1, time=0.1130318995565176s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=2, time=0.13851139973849058s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=1, time=0.09874550020322204s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=2, time=0.12178830010816455s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=2, time=0.13097150018438697s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=1, time=0.11291039967909455s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=2, time=0.11339220032095909s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='Negamax')(depths=[4 3], starting_player=2, winner=2, time=0.13247019983828068s, rounds_number=20) ========

# %%
df
# Out:
#    game_variant algorithm   depths  starting_player  winner      time  rounds
# 0           Nim   Negamax  [14, 7]                1       1  0.489057      14
# 1           Nim   Negamax   [4, 3]                1       2  0.104461      17
# 2           Nim   Negamax  [14, 7]                2       1  0.638690      17
# 3           Nim   Negamax   [4, 3]                2       1  0.085030      17
# 4         Nimby   Negamax  [14, 7]                1       1  0.592242      18
# 5         Nimby   Negamax  [14, 7]                1       1  0.523082      16
# 6         Nimby   Negamax  [14, 7]                1       1  0.480677      14
# 7         Nimby   Negamax  [14, 7]                1       1  0.576452      16
# 8         Nimby   Negamax  [14, 7]                1       2  0.577762      17
# 9         Nimby   Negamax  [14, 7]                1       1  0.581696      16
# 10        Nimby   Negamax  [14, 7]                1       1  0.587039      18
# 11        Nimby   Negamax  [14, 7]                1       1  0.561839      16
# 12        Nimby   Negamax  [14, 7]                1       1  0.477409      14
# 13        Nimby   Negamax  [14, 7]                1       2  0.517484      17
# 14        Nimby   Negamax   [4, 3]                1       2  0.110102      19
# 15        Nimby   Negamax   [4, 3]                1       1  0.122394      18
# 16        Nimby   Negamax   [4, 3]                1       2  0.120236      19
# 17        Nimby   Negamax   [4, 3]                1       1  0.095906      18
# 18        Nimby   Negamax   [4, 3]                1       2  0.109502      19
# 19        Nimby   Negamax   [4, 3]                1       2  0.108351      19
# 20        Nimby   Negamax   [4, 3]                1       2  0.104294      19
# 21        Nimby   Negamax   [4, 3]                1       1  0.100439      18
# 22        Nimby   Negamax   [4, 3]                1       1  0.112136      18
# 23        Nimby   Negamax   [4, 3]                1       2  0.097118      17
# 24        Nimby   Negamax  [14, 7]                2       1  0.763706      17
# 25        Nimby   Negamax  [14, 7]                2       2  0.687031      18
# 26        Nimby   Negamax  [14, 7]                2       2  0.683074      18
# 27        Nimby   Negamax  [14, 7]                2       2  0.678875      18
# 28        Nimby   Negamax  [14, 7]                2       1  0.663975      15
# 29        Nimby   Negamax  [14, 7]                2       2  0.694773      18
# 30        Nimby   Negamax  [14, 7]                2       2  0.694435      18
# 31        Nimby   Negamax  [14, 7]                2       2  0.686415      18
# 32        Nimby   Negamax  [14, 7]                2       1  0.728125      19
# 33        Nimby   Negamax  [14, 7]                2       1  0.664131      17
# 34        Nimby   Negamax   [4, 3]                2       1  0.112006      19
# 35        Nimby   Negamax   [4, 3]                2       1  0.106473      17
# 36        Nimby   Negamax   [4, 3]                2       1  0.113032      19
# 37        Nimby   Negamax   [4, 3]                2       2  0.138511      20
# 38        Nimby   Negamax   [4, 3]                2       1  0.098746      17
# 39        Nimby   Negamax   [4, 3]                2       2  0.121788      18
# 40        Nimby   Negamax   [4, 3]                2       2  0.130972      20
# 41        Nimby   Negamax   [4, 3]                2       1  0.112910      19
# 42        Nimby   Negamax   [4, 3]                2       2  0.113392      18
# 43        Nimby   Negamax   [4, 3]                2       2  0.132470      20

# %% [markdown]
# ### Negamax without alpha, beta pruning

# %%
from easyAI.AI.Negamax import inf

class NoPruningNegamax:

    def __init__(self, depth: int, scoring: Optional[Callable] = None, tt: Optional[TranspositionTable] = None) -> None:
        self.depth: int = depth
        self.scoring: Optional[Callable] = scoring
        self.tt: Optional[TranspositionTable] = tt

    def __call__(self, game: TwoPlayerGame) -> str:
        """
        Returns the AI's best move given the current state of the game.
        """

        scoring = (
            self.scoring if self.scoring else (lambda g: g.scoring())
        )  # horrible hack

        self.alpha = NoPruningNegamax.no_pruning_negamax(
            game,
            self.depth,
            self.depth,
            scoring,
            self.tt,
        )
        return game.ai_move # To jest dynamicznie dawana zmienna do obiektu klasy, bez konsultacji z faktyczną klasą gry. Rozwiązanie twórcy "easyAI" XD
    
    @staticmethod
    def no_pruning_negamax(game: TwoPlayerGame, depth: int, original_depth: int, scoring: Callable, tt: Optional[TranspositionTable] = None) -> float | int:
        """
		This implements Negamax with transposition tables.
		This method is not meant to be used directly. See ``easyAI.Negamax``
		for an example of practical use.
		This function is implemented (almost) according to
		http://en.wikipedia.org/wiki/Negamax
		"""
    
        # Is there a transposition table and is this game in it ?
        lookup = None if (tt is None) else tt.lookup(game)
    
        if lookup is not None:
            # The game has been visited in the past
    
            if lookup["depth"] >= depth:
                value = lookup["value"]
                if depth == original_depth:
                    game.ai_move = lookup["move"]
                return value
    
        if (depth == 0) or game.is_over():
            # NOTE: the "depth" variable represents the depth left to recurse into,
            # so the smaller it is, the deeper we are in the negamax recursion.
            # Here we add 0.001 as a bonus to signify that victories in less turns
            # have more value than victories in many turns (and conversely, defeats
            # after many turns are preferred over defeats in less turns)
            return scoring(game) * (1 + 0.001 * depth)
    
        if lookup is not None:
            # Put the supposedly best move first in the list
            possible_moves = game.possible_moves()
            possible_moves.remove(lookup["move"])
            possible_moves = [lookup["move"]] + possible_moves
    
        else:
            possible_moves = game.possible_moves()
    
        state = game
        best_move = possible_moves[0]
        if depth == original_depth:
            state.ai_move = possible_moves[0]
    
        best_value = -inf
        unmake_move = hasattr(state, "unmake_move")
    
        for move in possible_moves:
    
            if not unmake_move:
                game = state.copy()  # re-initialize move
    
            game.make_move(move)
            game.switch_player()
    
            move_score = -NoPruningNegamax.no_pruning_negamax(game, depth - 1, original_depth, scoring, tt)
    
            if unmake_move:
                game.switch_player()
                game.unmake_move(move)
    
            # bestValue = max( bestValue,  move_score )
            if best_value < move_score:
                best_value = move_score
                best_move = move
                if depth == original_depth:
                    state.ai_move = move
    
        if tt is not None:
    
            assert best_move in possible_moves
            tt.store(
                game=state,
                depth=depth,
                value=best_value,
                move=best_move,
            )
    
        return best_value

# %% [markdown]
# ### No Pruning Negamax - Deterministic

# %%
results: map = map(create_environment(game_type=Nim, solving_algorithm=NoPruningNegamax, in_order=True), CONFIG_NIM)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nim', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=1, time=1.0231395000591874s, rounds_number=18) ========
# ======== Finished(game_type='Nim', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.3791625997982919s, rounds_number=18) ========

# %%
results: map = map(create_environment(game_type=Nim, solving_algorithm=NoPruningNegamax, in_order=False), CONFIG_NIM)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nim', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.1150198001414537s, rounds_number=19) ========
# ======== Finished(game_type='Nim', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.2775515001267195s, rounds_number=17) ========

# %%
df
# Out:
#    game_variant         algorithm   depths  starting_player  winner      time  \
# 0           Nim           Negamax  [14, 7]                1       1  0.489057
# 1           Nim           Negamax   [4, 3]                1       2  0.104461
# 2           Nim           Negamax  [14, 7]                2       1  0.638690
# 3           Nim           Negamax   [4, 3]                2       1  0.085030
# 4         Nimby           Negamax  [14, 7]                1       1  0.592242
# 5         Nimby           Negamax  [14, 7]                1       1  0.523082
# 6         Nimby           Negamax  [14, 7]                1       1  0.480677
# 7         Nimby           Negamax  [14, 7]                1       1  0.576452
# 8         Nimby           Negamax  [14, 7]                1       2  0.577762
# 9         Nimby           Negamax  [14, 7]                1       1  0.581696
# 10        Nimby           Negamax  [14, 7]                1       1  0.587039
# 11        Nimby           Negamax  [14, 7]                1       1  0.561839
# 12        Nimby           Negamax  [14, 7]                1       1  0.477409
# 13        Nimby           Negamax  [14, 7]                1       2  0.517484
# 14        Nimby           Negamax   [4, 3]                1       2  0.110102
# 15        Nimby           Negamax   [4, 3]                1       1  0.122394
# 16        Nimby           Negamax   [4, 3]                1       2  0.120236
# 17        Nimby           Negamax   [4, 3]                1       1  0.095906
# 18        Nimby           Negamax   [4, 3]                1       2  0.109502
# 19        Nimby           Negamax   [4, 3]                1       2  0.108351
# 20        Nimby           Negamax   [4, 3]                1       2  0.104294
# 21        Nimby           Negamax   [4, 3]                1       1  0.100439
# 22        Nimby           Negamax   [4, 3]                1       1  0.112136
# 23        Nimby           Negamax   [4, 3]                1       2  0.097118
# 24        Nimby           Negamax  [14, 7]                2       1  0.763706
# 25        Nimby           Negamax  [14, 7]                2       2  0.687031
# 26        Nimby           Negamax  [14, 7]                2       2  0.683074
# 27        Nimby           Negamax  [14, 7]                2       2  0.678875
# 28        Nimby           Negamax  [14, 7]                2       1  0.663975
# 29        Nimby           Negamax  [14, 7]                2       2  0.694773
# 30        Nimby           Negamax  [14, 7]                2       2  0.694435
# 31        Nimby           Negamax  [14, 7]                2       2  0.686415
# 32        Nimby           Negamax  [14, 7]                2       1  0.728125
# 33        Nimby           Negamax  [14, 7]                2       1  0.664131
# 34        Nimby           Negamax   [4, 3]                2       1  0.112006
# 35        Nimby           Negamax   [4, 3]                2       1  0.106473
# 36        Nimby           Negamax   [4, 3]                2       1  0.113032
# 37        Nimby           Negamax   [4, 3]                2       2  0.138511
# 38        Nimby           Negamax   [4, 3]                2       1  0.098746
# 39        Nimby           Negamax   [4, 3]                2       2  0.121788
# 40        Nimby           Negamax   [4, 3]                2       2  0.130972
# 41        Nimby           Negamax   [4, 3]                2       1  0.112910
# 42        Nimby           Negamax   [4, 3]                2       2  0.113392
# 43        Nimby           Negamax   [4, 3]                2       2  0.132470
# 44          Nim  NoPruningNegamax  [14, 7]                1       1  1.023140
# 45          Nim  NoPruningNegamax   [4, 3]                1       1  0.379163
# 46          Nim  NoPruningNegamax  [14, 7]                2       1  1.115020
# 47          Nim  NoPruningNegamax   [4, 3]                2       1  0.277552
#
#     rounds
# 0       14
# 1       17
# 2       17
# 3       17
# 4       18
# 5       16
# 6       14
# 7       16
# 8       17
# 9       16
# 10      18
# 11      16
# 12      14
# 13      17
# 14      19
# 15      18
# 16      19
# 17      18
# 18      19
# 19      19
# 20      19
# 21      18
# 22      18
# 23      17
# 24      17
# 25      18
# 26      18
# 27      18
# 28      15
# 29      18
# 30      18
# 31      18
# 32      19
# 33      17
# 34      19
# 35      17
# 36      19
# 37      20
# 38      17
# 39      18
# 40      20
# 41      19
# 42      18
# 43      20
# 44      18
# 45      18
# 46      19
# 47      17

# %% [markdown]
# ### No Pruning Negamax - Non-Deterministic

# %%
results: map = map(create_environment(game_type=Nimby, solving_algorithm=NoPruningNegamax, in_order=True), CONFIG_NIMBY)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=2, time=1.1825942997820675s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.993637700099498s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=2, time=1.0258918995968997s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=1, time=1.0240775998681784s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=2, time=0.9780989997088909s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=1, time=1.025754800066352s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=2, time=1.0838084002025425s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=2, time=1.0979269999079406s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.9772157003171742s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=1, winner=2, time=1.023930000141263s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.312678599730134s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.29997050017118454s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.38938979990780354s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.33417379995808005s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.3707538000307977s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.38724249973893166s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.38479229994118214s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.40681449975818396s, rounds_number=23) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.36085390020161867s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.3184628002345562s, rounds_number=18) ========

# %%
results: map = map(create_environment(game_type=Nimby, solving_algorithm=NoPruningNegamax, in_order=False), CONFIG_NIMBY)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.0632732002995908s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.0325060999020934s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.0628386000171304s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.1211616001091897s, rounds_number=23) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.0926005002111197s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.2093493002466857s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=2, time=1.08648999966681s, rounds_number=22) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.2077362001873553s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.9605479999445379s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[14  7], starting_player=2, winner=1, time=1.0846052998676896s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.27510059997439384s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.2746472996659577s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.30982720013707876s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.35240460000932217s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.3205009000375867s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.37007310008630157s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.3641623998992145s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.2784039000980556s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.39497229969128966s, rounds_number=22) ========
# ======== Finished(game_type='Nimby', solving_algorithm='NoPruningNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.2921691997908056s, rounds_number=19) ========

# %%
df
# Out:
#    game_variant         algorithm   depths  starting_player  winner      time  \
# 0           Nim           Negamax  [14, 7]                1       1  0.489057
# 1           Nim           Negamax   [4, 3]                1       2  0.104461
# 2           Nim           Negamax  [14, 7]                2       1  0.638690
# 3           Nim           Negamax   [4, 3]                2       1  0.085030
# 4         Nimby           Negamax  [14, 7]                1       1  0.592242
# ..          ...               ...      ...              ...     ...       ...
# 83        Nimby  NoPruningNegamax   [4, 3]                2       2  0.370073
# 84        Nimby  NoPruningNegamax   [4, 3]                2       1  0.364162
# 85        Nimby  NoPruningNegamax   [4, 3]                2       1  0.278404
# 86        Nimby  NoPruningNegamax   [4, 3]                2       2  0.394972
# 87        Nimby  NoPruningNegamax   [4, 3]                2       1  0.292169
#
#     rounds
# 0       14
# 1       17
# 2       17
# 3       17
# 4       18
# ..     ...
# 83      20
# 84      21
# 85      17
# 86      22
# 87      19
#
# [88 rows x 7 columns]

# %% [markdown]
# ## Expected-minimax

# %%
TwoPlayerGame.ask_move = ask_move_original

# %%
"""
The standard AI algorithm of easyAI is Negamax with alpha-beta pruning
and (optionally), transposition tables.
"""

LOWERBOUND, EXACT, UPPERBOUND = -1, 0, 1


def custom_negamax(game, depth, origDepth, scoring, alpha=+inf, beta=-inf, tt=None):
    """
    This implements Negamax with transposition tables.
    This method is not meant to be used directly. See ``easyAI.Negamax``
    for an example of practical use.
    This function is implemented (almost) according to
    http://en.wikipedia.org/wiki/Negamax
    """

    alphaOrig = alpha

    # Is there a transposition table and is this game in it ?
    lookup = None if (tt is None) else tt.lookup(game)

    if lookup is not None:
        # The game has been visited in the past

        if lookup["depth"] >= depth:
            flag, value = lookup["flag"], lookup["value"]
            if flag == EXACT:
                if depth == origDepth:
                    game.ai_move = lookup["move"]
                return value
            elif flag == LOWERBOUND:
                alpha = max(alpha, value)
            elif flag == UPPERBOUND:
                beta = min(beta, value)

            if alpha >= beta:
                if depth == origDepth:
                    game.ai_move = lookup["move"]
                return value

    if (depth == 0) or game.is_over():
        # NOTE: the "depth" variable represents the depth left to recurse into,
        # so the smaller it is, the deeper we are in the negamax recursion.
        # Here we add 0.001 as a bonus to signify that victories in less turns
        # have more value than victories in many turns (and conversely, defeats
        # after many turns are preferred over defeats in less turns)
        return scoring(game) * (1 + 0.001 * depth)

    if lookup is not None:
        # Put the supposedly best move first in the list
        possible_moves = game.possible_moves()
        possible_moves.remove(lookup["move"])
        possible_moves = [lookup["move"]] + possible_moves

    else:

        possible_moves = game.possible_moves()

    state = game
    best_move = possible_moves[0]
    if depth == origDepth:
        state.ai_move = possible_moves[0]

    bestValue = -inf
    unmake_move = hasattr(state, "unmake_move")

    for move in possible_moves:

        if not unmake_move:
            game = state.copy()  # re-initialize move

        game.make_move(move)
        game.switch_player()

        move_alpha = -custom_negamax(game, depth - 1, origDepth, scoring, -beta, -alpha, tt)

        if unmake_move:
            game.switch_player()
            game.unmake_move(move)

        # bestValue = max( bestValue,  move_alpha )
        if bestValue < move_alpha:
            bestValue = move_alpha
            best_move = move

        if alpha < move_alpha:
            alpha = move_alpha
            # best_move = move
            if depth == origDepth:
                state.ai_move = move
            if alpha >= beta:
                break

    if tt is not None:

        assert best_move in possible_moves
        tt.store(
            game=state,
            depth=depth,
            value=bestValue,
            move=best_move,
            flag=UPPERBOUND
            if (bestValue <= alphaOrig)
            else (LOWERBOUND if (bestValue >= beta) else EXACT),
        )

    return bestValue


class CustomNegamax:
    """
    This implements Negamax on steroids. The following example shows
    how to set up the AI and play a Connect Four game:

        >>> from easyAI.games import ConnectFour
        >>> from easyAI import Negamax, Human_Player, AI_Player
        >>> scoring = lambda game: -100 if game.lose() else 0
        >>> ai_algo = Negamax(8, scoring) # AI will think 8 turns in advance
        >>> game = ConnectFour([Human_Player(), AI_Player(ai_algo)])
        >>> game.play()

    Parameters
    -----------

    depth:
      How many moves in advance should the AI think ?
      (2 moves = 1 complete turn)

    scoring:
      A function f(game)-> score. If no scoring is provided
         and the game object has a ``scoring`` method it will be used.

    win_score:
      Score above which the score means a win. This will be
        used to speed up computations if provided, but the AI will not
        differentiate quick defeats from long-fought ones (see next
        section).

    tt:
      A transposition table (a table storing game states and moves)
      scoring: can be none if the game that the AI will be given has a
      ``scoring`` method.

    Notes
    -----

    The score of a given game is given by

    >>> scoring(current_game) - 0.01*sign*current_depth

    for instance if a loss is -100 points, then losing after 4 moves
    will score -99.96 points but losing after 8 moves will be -99.92
    points. Thus, the AI will choose the move that leads to defeat in
    8 turns, which makes it more difficult for the (human) opponent.
    This will not always work if a ``win_score`` argument is provided.

    """

    def __init__(self, depth: int, scoring=None, win_score=+inf, tt=None):
        self.scoring = scoring
        self.depth: int = depth
        self.tt = tt
        self.win_score = win_score

    def __call__(self, game):
        """
        Returns the AI's best move given the current state of the game.
        """

        scoring = (
            self.scoring if self.scoring else (lambda g: g.scoring())
        )  # horrible hack

        self.alpha = custom_negamax(
            game,
            self.depth,
            self.depth,
            scoring,
            -self.win_score,
            +self.win_score,
            self.tt,
        )
        return game.ai_move

# %% [markdown]
# ### Expecti-minimax z odcięciem alfa-beta - Deterministic

# %%
results: map = map(create_environment(game_type=Nim, solving_algorithm=CustomNegamax, in_order=True), CONFIG_NIM)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nim', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.5599456997588277s, rounds_number=14) ========
# ======== Finished(game_type='Nim', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.11285799974575639s, rounds_number=17) ========

# %%
results: map = map(create_environment(game_type=Nim, solving_algorithm=CustomNegamax, in_order=False), CONFIG_NIM)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nim', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6822254997678101s, rounds_number=17) ========
# ======== Finished(game_type='Nim', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.09262089990079403s, rounds_number=17) ========

# %%
df
# Out:
#    game_variant         algorithm   depths  starting_player  winner      time  \
# 0           Nim           Negamax  [14, 7]                1       1  0.489057
# 1           Nim           Negamax   [4, 3]                1       2  0.104461
# 2           Nim           Negamax  [14, 7]                2       1  0.638690
# 3           Nim           Negamax   [4, 3]                2       1  0.085030
# 4         Nimby           Negamax  [14, 7]                1       1  0.592242
# ..          ...               ...      ...              ...     ...       ...
# 87        Nimby  NoPruningNegamax   [4, 3]                2       1  0.292169
# 88          Nim     CustomNegamax  [14, 7]                1       1  0.559946
# 89          Nim     CustomNegamax   [4, 3]                1       2  0.112858
# 90          Nim     CustomNegamax  [14, 7]                2       1  0.682225
# 91          Nim     CustomNegamax   [4, 3]                2       1  0.092621
#
#     rounds
# 0       14
# 1       17
# 2       17
# 3       17
# 4       18
# ..     ...
# 87      19
# 88      14
# 89      17
# 90      17
# 91      17
#
# [92 rows x 7 columns]

# %% [markdown]
# ### Expecti-minimax z odcięciem alfa-beta - Non-Deterministic

# %%
results: map = map(create_environment(game_type=Nimby, solving_algorithm=CustomNegamax, in_order=True), CONFIG_NIMBY)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.5394711000844836s, rounds_number=14) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.6227005003020167s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.6153695001266897s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=2, time=0.6510666003450751s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.5248885997571051s, rounds_number=14) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=2, time=0.5758127998560667s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.5511847999878228s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=2, time=0.5553796999156475s, rounds_number=15) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=2, time=0.5266105998307467s, rounds_number=15) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=1, winner=1, time=0.6080769002437592s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.12562429998070002s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.10589680029079318s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.10071789985522628s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.1351664001122117s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.1098734000697732s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.11014169966802001s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.10993079980835319s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.11499049980193377s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=1, time=0.1195890000090003s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=1, winner=2, time=0.16464170021936297s, rounds_number=17) ========

# %%
results: map = map(create_environment(game_type=Nimby, solving_algorithm=CustomNegamax, in_order=False), CONFIG_NIMBY)
add_to_dataframe(df, list(results))
# Out:
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=2, time=0.6707362001761794s, rounds_number=16) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6983104003593326s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6906163999810815s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6905942000448704s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6965598999522626s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6847169999964535s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=2, time=0.7141989003866911s, rounds_number=20) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.658591500017792s, rounds_number=15) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=1, time=0.6269080000929534s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[14  7], starting_player=2, winner=2, time=0.6817932999692857s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.11794110015034676s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.10380150005221367s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.10017920006066561s, rounds_number=17) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.10496699996292591s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.1370091000571847s, rounds_number=21) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.1049639000557363s, rounds_number=18) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.16663100011646748s, rounds_number=24) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.12483360012993217s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=1, time=0.11588989989832044s, rounds_number=19) ========
# ======== Finished(game_type='Nimby', solving_algorithm='CustomNegamax')(depths=[4 3], starting_player=2, winner=2, time=0.13660269975662231s, rounds_number=20) ========

# %%
df
# Out:
#     game_variant      algorithm   depths  starting_player  winner      time  \
# 0            Nim        Negamax  [14, 7]                1       1  0.489057
# 1            Nim        Negamax   [4, 3]                1       2  0.104461
# 2            Nim        Negamax  [14, 7]                2       1  0.638690
# 3            Nim        Negamax   [4, 3]                2       1  0.085030
# 4          Nimby        Negamax  [14, 7]                1       1  0.592242
# ..           ...            ...      ...              ...     ...       ...
# 127        Nimby  CustomNegamax   [4, 3]                2       2  0.104964
# 128        Nimby  CustomNegamax   [4, 3]                2       2  0.166631
# 129        Nimby  CustomNegamax   [4, 3]                2       1  0.124834
# 130        Nimby  CustomNegamax   [4, 3]                2       1  0.115890
# 131        Nimby  CustomNegamax   [4, 3]                2       2  0.136603
#
#      rounds
# 0        14
# 1        17
# 2        17
# 3        17
# 4        18
# ..      ...
# 127      18
# 128      24
# 129      19
# 130      19
# 131      20
#
# [132 rows x 7 columns]

# %% [markdown]
# ### Analysis
#
# Added average time spend on computing the move, by all AI players.

# %%
df['avg_round_time'] = (df['time'] / df['rounds']).astype(np.float32)

# %%
print(f'Total computation time: {df["time"].sum()}s.')
print(f'Average game time: {df["time"].mean()}s.')
print(f'Average turn computation time: {df["avg_round_time"].mean()}s.')
# Out:
# Total computation time: 63.36517710098997s.
# Average game time: 0.4800392204620452s.
# Average turn computation time: 0.026333779096603394s.

# %%
df
# Out:
#     game_variant      algorithm   depths  starting_player  winner      time  \
# 0            Nim        Negamax  [14, 7]                1       1  0.489057
# 1            Nim        Negamax   [4, 3]                1       2  0.104461
# 2            Nim        Negamax  [14, 7]                2       1  0.638690
# 3            Nim        Negamax   [4, 3]                2       1  0.085030
# 4          Nimby        Negamax  [14, 7]                1       1  0.592242
# ..           ...            ...      ...              ...     ...       ...
# 127        Nimby  CustomNegamax   [4, 3]                2       2  0.104964
# 128        Nimby  CustomNegamax   [4, 3]                2       2  0.166631
# 129        Nimby  CustomNegamax   [4, 3]                2       1  0.124834
# 130        Nimby  CustomNegamax   [4, 3]                2       1  0.115890
# 131        Nimby  CustomNegamax   [4, 3]                2       2  0.136603
#
#      rounds  avg_round_time
# 0        14        0.034933
# 1        17        0.006145
# 2        17        0.037570
# 3        17        0.005002
# 4        18        0.032902
# ..      ...             ...
# 127      18        0.005831
# 128      24        0.006943
# 129      19        0.006570
# 130      19        0.006099
# 131      20        0.006830
#
# [132 rows x 8 columns]

# %%
PLAYER_1_NIM_WINS: Final[int] = len(df.where((df['winner'] == 1) & (df['game_variant'] == 'Nim')).dropna())
PLAYER_2_NIM_WINS: Final[int] = len(df.where((df['winner'] == 2) & (df['game_variant'] == 'Nim')).dropna())

# %%
print(f'Player 1 wins: {PLAYER_1_NIM_WINS} times in Nim games.')
print(f'Player 2 wins: {PLAYER_2_NIM_WINS} times in Nim games.')
print(f'Number of performed Nim games: {PLAYER_1_NIM_WINS + PLAYER_2_NIM_WINS}.')
# Out:
# Player 1 wins: 10 times in Nim games.
# Player 2 wins: 2 times in Nim games.
# Number of performed Nim games: 12.

# %%
PLAYER_1_NIMBY_WINS: Final[int] = len(df.where((df['winner'] == 1) & (df['game_variant'] == 'Nimby')).dropna())
PLAYER_2_NIMBY_WINS: Final[int] = len(df.where((df['winner'] == 2) & (df['game_variant'] == 'Nimby')).dropna())

# %%
print(f'Player 1 wins: {PLAYER_1_NIMBY_WINS} times in Nimby games.')
print(f'Player 2 wins: {PLAYER_2_NIMBY_WINS} times in Nimby games.')
print(f'Number of performed Nimby games: {PLAYER_1_NIMBY_WINS + PLAYER_2_NIMBY_WINS}.')
# Out:
# Player 1 wins: 68 times in Nimby games.
# Player 2 wins: 52 times in Nimby games.
# Number of performed Nimby games: 120.

# %%
print(f'Total number of games: {len(df)}.')

print(f'Player 1 wins: {PLAYER_1_NIM_WINS + PLAYER_1_NIMBY_WINS} times. Which is {((PLAYER_1_NIM_WINS + PLAYER_1_NIMBY_WINS) / len(df)) * 100:.2f}% of all games.')
print(f'Player 2 wins: {PLAYER_2_NIM_WINS + PLAYER_2_NIMBY_WINS} times. Which is {((PLAYER_2_NIM_WINS + PLAYER_2_NIMBY_WINS) / len(df)) * 100:.2f}% of all games.')
# Out:
# Total number of games: 132.
# Player 1 wins: 78 times. Which is 59.09% of all games.
# Player 2 wins: 54 times. Which is 40.91% of all games.

# %% [markdown]
# Save the results to a `.csv` file.

# %%
df.to_csv('results.csv', index=False)
